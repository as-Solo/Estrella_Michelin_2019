# %%
import sys
sys.path.append("../")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pycountry
import plotly.graph_objects as go
import plotly.express as px
import tkinter as tk

# %%
data = pd.read_csv('../data/estrellasMichelin.csv', index_col = 0)

# %%
data.head()
# Out:
#             name  year  latitude  longitude                 city      region  \
# 0         Amador  2019  48.25406   16.35915                 Wien     Austria
# 1        Manresa  2019  37.22761 -121.98071  South San Francisco  California
# 2           Benu  2019  37.78521 -122.39876        San Francisco  California
# 3         Quince  2019  37.79762 -122.40337        San Francisco  California
# 4  Atelier Crenn  2019  37.79835 -122.43586        San Francisco  California
#
#   zipCode       cuisine  price  \
# 0    1190      Creative  $$$$$
# 1   95030  Contemporary   $$$$
# 2   94105         Asian   $$$$
# 3   94133  Contemporary   $$$$
# 4   94123  Contemporary   $$$$
#
#                                                  url  media_precios_€  \
# 0  https://guide.michelin.com/at/en/vienna/wien/r...           175.00
# 1  https://guide.michelin.com/us/en/california/so...           231.00
# 2  https://guide.michelin.com/us/en/california/sa...           273.00
# ...

# %%
visualizacion = data.loc[(data.region == 'California') & (data.cuisine == 'Contemporary')  (data['media_precios_€'] > 100)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     265         #  (xint or xbool) and (yint or bool)
# --> 266         result = op(x, y)
#     267     except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'str' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-3f036a195d8a> in <module>
# ----> 1 visualizacion = data.loc[data.region & (data.cuisine == 'Contemporary') & (data['media_precios_€'] > 100)]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ...

# %%
visualizacion[['name', 'city', 'region', 'cuisine', 'media_precios_€', 'phone', 'restaurant_web']]
# Out:
#                  name                 city      region       cuisine  \
# 1             Manresa  South San Francisco  California  Contemporary
# 3              Quince        San Francisco  California  Contemporary
# 4       Atelier Crenn        San Francisco  California  Contemporary
# 5  The French Laundry        San Francisco  California  Contemporary
# 7        SingleThread        San Francisco  California  Contemporary
#
#    media_precios_€            phone             restaurant_web
# 1           231.00  +1 408-354-4330  www.manresarestaurant.com
# 3           207.06  +1 415-775-8500   www.quincerestaurant.com
# 4           250.32  +1 415-440-0460       www.ateliercrenn.com
# 5           336.00  +1 707-944-2380       www.thomaskeller.com
# 7           277.20  +1 707-723-4646  www.singlethreadfarms.com
