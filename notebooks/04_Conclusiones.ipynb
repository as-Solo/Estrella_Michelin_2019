# %% [markdown]
# ![portada_Conclusiones.jpg](attachment:portada_Conclusiones.jpg)

# %% [markdown]
# ### Una vez realizado todo el trabajo previo, nos disponemos a observar los gráficos obtenidos y a sacar conclusiones de los mismos.

# %% [markdown]
# ####  Empecemos con la gráfica que muestra el precio medio de cada Restaurante.

# %% [markdown]
# ![MediaPreciosRestaurante.png](attachment:MediaPreciosRestaurante.png)

# %% [markdown]
# Podemos observar como la gráfica se comporta de la manera esperada, dado que el valor medio está calculado con la mediana, un mayoría de los restaurantes oscilan alrededor del precio medio y aproximádamente, la mitad de la tabla se sitúa por encima y la otra mitad por debajo. Recordar en este punto que los valores en cero no se han tenido en cuenta a la hora de hacer el precio medio.

# %% [markdown]
# #### Pasemos a verificar si afecta el tipo de cocina que se hace en los distintos Restaurantes para que el precio medio varíe.

# %% [markdown]
# ![MediaPreciosCocina.png](attachment:MediaPreciosCocina.png)

# %% [markdown]
# En la gráfica se puede ver claramente como la cocina 'Creativa' eleva el coste a casi el doble del precio medio. Seguida de 'Sushi', 'Asiática' y 'Japonesa' (podríamos intentar analizar en proyectos futuros si tiene algo que ver con la moda que ha habido con el sushi y la comida japonesa) y por último la comida 'Contemporánea'. Cinco estilos de cocina son los que copan los precios más altos, con un claro exponente desmarcándose del resto que es la comida 'Creativa'. Podemos decir que sí afecta el estilo de cocina en el precio del Restaurante.

# %% [markdown]
# ####  Verífiquemos si pasa lo mismo pero con la zona del mundo en la que se encuentren los Restaurantes

# %% [markdown]
# ![MediaPreciosRegion.png](attachment:MediaPreciosRegion.png)

# %% [markdown]
# Podemos ver como los países escandinavos están muy por encima de la media. Evidentemente, podemos llegar a la conclusión de que la situación del Restaurante va a afectar a su precio medio. La razón más obvia, cuanto más rico sea el país más costará cualquier cosa. Podríamos hacer una aproximación más realista del precio, si lo comparasemos con el producto interior bruto de cada país, para ver la relación entre lo rico que es ese país y el coste medio de sus restaurantes.

# %% [markdown]
# #### Y visualicemos ese último gráfico poniéndolo en un contexto geográfico.

# %% [markdown]
# ![MapaMundial.png](attachment:MapaMundial.png)
